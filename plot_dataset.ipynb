# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
DATA_ROOT = f'/export/data/vgiusepp/odisseo_data/data_fix_position/sbi-sim/data/sbi-benchmarks/odisseo_AllParameters'
print(f"DATA_ROOT: {DATA_ROOT}")
# Out:
# DATA_ROOT: /export/data/vgiusepp/odisseo_data/data_fix_position/sbi-sim/data/sbi-benchmarks/odisseo_AllParameters

# %%
! ls {DATA_ROOT}
# Out:
# num_observation_1     num_observation_401  num_observation_705
# num_observation_10    num_observation_402  num_observation_706
# num_observation_100   num_observation_403  num_observation_707
# num_observation_1000  num_observation_404  num_observation_708
# num_observation_101   num_observation_405  num_observation_709
# num_observation_102   num_observation_406  num_observation_71
# num_observation_103   num_observation_407  num_observation_710
# num_observation_104   num_observation_408  num_observation_711
# num_observation_105   num_observation_409  num_observation_712
# num_observation_106   num_observation_41   num_observation_713
# num_observation_107   num_observation_410  num_observation_714
# num_observation_108   num_observation_411  num_observation_715
# num_observation_109   num_observation_412  num_observation_716
# num_observation_11    num_observation_413  num_observation_717
# num_observation_110   num_observation_414  num_observation_718
# ...

# %%
theta_10000 = np.load(f"{DATA_ROOT}/theta_100000.npy")

theta_10000[:, [1, 3, 5]] = 10**theta_10000[:, [1, 3, 5]] 
theta_10000.shape
# Out:
# (100000, 7)

# %%
for i in range(7):
    plt.hist(theta_10000[:, i], bins=50)
    plt.show()
